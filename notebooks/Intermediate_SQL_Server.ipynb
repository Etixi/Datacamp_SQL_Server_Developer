# %% [markdown]
# #**COURS INTERACTIF: Serveur SQL intermédiaire**
#
# + *4 heures*
# + *14 Vidéos*
# + *47 exercices*
# + *48 727 participants*
# + *3 850 XP*
#
#
# <img src="https://www.datacamp.com/statement-of-accomplishment/badge/course/820e796111e1be7039d24e06d1f53f9200de7e37.png"/>
#
# ####**Description du cours**
#
# + ***Une majorité de données est stockée dans des bases de données et connaître les outils nécessaires pour analyser et nettoyer les données directement dans les bases de données est indispensable. Ce cours se concentre sur T-SQL, la version de SQL utilisée dans Microsoft SQL Server, nécessaire à l'analyse des données. Vous apprendrez plusieurs concepts dans ce cours, tels que la gestion des données manquantes, l'utilisation des dates et le calcul de statistiques récapitulatives à l'aide de requêtes avancées. Après avoir terminé ce cours, vous aurez les compétences nécessaires pour analyser les données et fournir des informations rapidement et facilement.***
#
# ####**1) Résumé des données**
#
# + ***L'une des premières étapes de l'analyse des données consiste à examiner les données au moyen d'agrégations. Ce chapitre explique comment créer des agrégations dans SQL Server, une première étape courante dans l'exploration de données. Vous nettoyerez également les données manquantes et catégoriserez les données dans des bacs avec des instructions CASE.***
#
# |OBJECTIFS|
# |---------|
# Analyse de données avec agrégations
# Création d'agrégations
# Création d'agrégations groupées
# Traiter les données manquantes
# Suppression des valeurs manquantes
# Imputation des valeurs manquantes (I)
# Imputation des valeurs manquantes (II)
# Regrouper les données avec CASE
# Utilisation des instructions CASE
# Créer plusieurs groupes avec CASE
#
# ####**2) Fonctions mathématiques**
#
# + ***Ce chapitre explore les opérations mathématiques essentielles telles que l'arrondissement des nombres, le calcul des carrés et des racines carrées et le comptage des enregistrements. Vous travaillerez également avec des dates dans ce chapitre !***
#
# |OBJECTIFS|
# |---------|
# Comptage et totaux
# Calcul du total
# Compter le nombre de lignes
# Rendez-vous
# Quelle fonction de date devriez-vous utiliser ?
# Compter le nombre de jours entre les dates
# Ajouter des jours à une date
# Arrondir et tronquer
# Arrondir les nombres
# Tronquer des nombres
# Plus de fonctions mathématiques
# Calcul de la valeur absolue
# Calcul des carrés et des racines carrées
#
# ####**3) Traitement des données dans SQL Server**
#
# + ***Dans ce chapitre, vous allez créer des variables et écrire des boucles while pour traiter des données. Vous écrirez également des requêtes complexes en utilisant des tables dérivées et des expressions de table communes.***
#
# |OBJECTIFS|
# |---------|
# Boucles WHILE
# Créer et utiliser des variables
# Création d'une boucle WHILE
# Tables dérivées
# Requêtes avec tables dérivées (I)
# Requêtes avec tables dérivées (II)
# Expressions de table courantes
# Syntaxe CTE
# Création de CTE (I)
# Création de CTE (II)
#
# ####**4) Fonctions de la fenêtre**
#
# + ***Dans le dernier chapitre de ce cours, vous travaillerez avec des partitions de données et des fonctions de fenêtre pour calculer plusieurs statistiques récapitulatives et verrez à quel point il est facile de créer des totaux cumulés et de calculer le mode des colonnes numériques.***
#
# |OBJECTIFS|
# |---------|
# Fonctions de fenêtre dans T-SQL
# Fonctions de fenêtre avec agrégations (I)
# Fonctions de fenêtre avec agrégations (II)
# Fonctions de fenêtre communes
# Connaissez-vous les fonctions des fenêtres ?
# Première valeur dans une fenêtre
# Valeurs précédentes et suivantes
# Augmentation de la complexité des fenêtres
# Création de totaux cumulés
# Attribuer des numéros de ligne
# Utilisation des fenêtres pour les fonctions statistiques
# Calcul de l'écart type
# Mode de calcul (I)
# Mode de calcul (II)

# %% [markdown]
# ####**1. Bienvenue**
#
# + ***Bienvenue dans ce cours DataCamp sur le développement de SQL pour la science des données. Je m'appelle Ginger Grant et je serai votre instructeur pour ce cours. Je travaille avec Transact SQL, communément appelé T-SQL, la version de SQL utilisée dans SQL Server depuis plus de 10 ans et j'ai été reconnu par Microsoft comme MVP de la plateforme de données et formateur certifié. En tant que président du cabinet de conseil en analyse de données, Desert Isle Group, je propose des formations et développe des solutions utilisant SQL et d'autres outils pour aider les clients à trouver un sens à leurs données.***
#
# ####**2. Aperçu du cours**
#
# + ***Dans ce cours, nous allons utiliser SQL pour analyser des données pour une analyse exploratoire des données. Dans le premier chapitre, nous examinerons des informations récapitulatives, couramment utilisées dans d'autres langages tels que R et Python. Dans le chapitre 2, nous allons examiner certaines fonctions SQL utiles pour manipuler des données à l'aide de fonctions mathématiques et de date. Le chapitre 3 contient les techniques de modification des données, et enfin le chapitre 4 les fonctions de fenêtrage TSQL.***
#
# ####**3. Explorer les données avec agrégation**
#
# + ***Les Data Scientists passent beaucoup de temps à analyser et agréger les données en générant des statistiques récapitulatives telles que les valeurs moyennes, minimales et maximales des colonnes. Si vos données existent dans une base de données, le moyen le plus rapide de générer des statistiques récapitulatives consiste à utiliser SQL.***
#
# ####**4. Exploration des données avec des indicateurs économiques**
#
# + ***Dans les vidéos de ce chapitre, nous exécuterons des requêtes sur la table EconomicIndicators. Les données affichent par pays plusieurs statistiques intéressantes comme le produit intérieur brut ou le PIB et l'utilisation d'Internet. Un échantillon de la table est inclus ici qui comprend différents nombres entiers, texte, flottants.***
#
# ####**5. Statistiques récapitulatives communes**
#
# + ***Vous pouvez calculer des statistiques récapitulatives courantes telles que le minimum, le maximum et la moyenne de chaque colonne en utilisant respectivement les fonctions `MIN, MAX et AVG`.***
#
# ####**6. Statistiques récapitulatives communes dans T-SQL**
#
# + ***omme vous pouvez le voir sur la diapositive, vous devez transmettre le nom de la colonne aux fonctions concernées pour calculer les statistiques récapitulatives. Notez que tous les mots clés tels que `SELECT, FROM et WHERE` ainsi que les noms de fonction sont écrits en majuscules. T-SQL est par défaut insensible à la casse, vous n'avez donc pas à les écrire dans un cas particulier, mais la capitalisation des mots-clés et des noms de fonctions est une convention standard. Comme vous l'avez vu dans l'exemple précédent,***
#
# ####**7. Filtrage des données récapitulatives avec WHERE**
#
# + ***ces fonctions calculent par défaut des statistiques récapitulatives pour toute la colonne. Que se passe-t-il si vous souhaitez calculer ces statistiques pour un groupe spécifique, disons uniquement pour les Îles Salomon ? Vous pouvez le faire en ajoutant la clause `WHERE` comme indiqué ici.***
#
# ####**8. Sous-totalisation des agrégations en groupes avec GROUP BY**
#
# + ***Dans l'exemple précédent, nous avons agrégé pour toute la table. Ici, vous voyez que pour calculer ces statistiques pour chaque pays, vous devrez utiliser la clause GROUP BY comme indiqué ici.***
#
# ####**9. AVOIR est le OÙ pour les agrégations**
#
# + ***Maintenant, si vous voulez aller plus loin en renvoyant uniquement les pays où InternetUse est supérieur à 100, vous ne pouvez pas utiliser la clause WHERE. Lorsque vous souhaitez filtrer sur des calculs contenant GROUP BY, vous pouvez utiliser la clause HAVING pour filtrer les lignes.***
#
# ####**10. AVOIR est le OÙ pour les agrégations**
#
# + ***Voici un exemple complet utilisant la clause HAVING. Nous filtrons la requête pour n'afficher que les pays ayant une utilisation d'Internet supérieure à 100 heures par mois.***
#
# ####**11. Examen des données OVNI dans le tableau des incidents**
#
# + ***Dans les exercices suivants, vous vous entraînerez à calculer des statistiques récapitulatives à l'aide des données recueillies auprès de MUFON, le réseau Mutual UFO sur tous les sites inexpliqués du monde entier dans le tableau Incidents.***
#
# ####**12. Entraînons-nous !**
#
# + ***Essayons maintenant quelques exemples***

# %% [markdown]
# ###**EXERCICES**
# ####**Création d'agrégations**
#
# + ***Ce chapitre utilise des données recueillies par le National UFO Reporting Center. Les données sont contenues dans le tableau Incidents et dans cette leçon, vous allez agréger des valeurs dans la colonne DurationSeconds.***
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui renverra les valeurs moyennes, minimales et maximales de la colonne DurationSeconds.

# %%
-- Calculate the average, minimum and maximum
SELECT AVG(DurationSeconds) AS Average,
       MIN(DurationSeconds) AS Minimum,
       MAX(DurationSeconds) AS Maximum
FROM Incidents

# %% [markdown]
# ####**Création d'agrégations groupées**
#
# + ***Vous pouvez calculer des statistiques pour chaque groupe à l'aide de `GROUP BY`. Par exemple, vous pouvez calculer la valeur maximale pour chaque état à l'aide de la requête suivante :***
#
#       SELECT State, MAX(DurationSeconds)
#       FROM Incidents
#       GROUP BY State
#
# + Pour filtrer encore plus, par exemple, pour trouver les valeurs des états où la valeur maximale est supérieure à 10, vous pouvez utiliser la clause `HAVING`.
#
# ####**Consignes**
# + Écrivez une requête T-SQL pour calculer les valeurs moyennes, minimales et maximales de la colonne DurationSeconds regroupée par Shape. Vous devez sélectionner une colonne supplémentaire. Qu'est-ce que c'est?
# + Mettez à jour la requête pour renvoyer uniquement les enregistrements où le minimum de la colonne DurationSeconds est supérieur à 1.

# %%
-- Calculate the aggregations by Shape
SELECT Shape,
       AVG(DurationSeconds) AS Average,
       MIN(DurationSeconds) AS Minimum,
       MAX(DurationSeconds) AS Maximum
FROM Incidents
GROUP BY Shape

# %%
-- Calculate the aggregations by Shape
SELECT Shape,
       AVG(DurationSeconds) AS Average,
       MIN(DurationSeconds) AS Minimum,
       MAX(DurationSeconds) AS Maximum
FROM Incidents
GROUP BY Shape
-- Return records where minimum of DurationSeconds is greater than 1
HAVING MIN(DurationSeconds) > 1

# %% [markdown]
# ####**1. Trouver et résoudre les données manquantes**
#
# + ***Dans cette leçon, vous allez voir comment identifier et résoudre les données manquantes.***
#
# ####**2. Détecter les valeurs manquantes**
#
# + ***Les données manquantes sont monnaie courante. En SQL, les données manquantes sont représentées par `NULL`. Étant donné que `NULL` n'est pas une valeur, vous ne pouvez pas utiliser le signe ÉGAL ou tout autre opérateur pour rechercher ou comparer des valeurs `NULL`, à la place, vous devez utiliser `IS NULL et IS NOT NULL`.***
#
# 3. Renvoyer aucune valeur NULL dans T-SQL
#
# + ***Pour vérifier s'il y a une valeur manquante dans une colonne, vous pouvez utiliser `IS NOT NULL`. Par exemple, pour renvoyer toutes les lignes sans aucune valeur manquante dans InternetUse, vous pouvez ajouter la clause WHERE InternetUse `IS NOT NULL` comme indiqué ici sur la dernière ligne de la requête.***
#
# ####**4. Détection des NULL dans T-SQL**
#
# + ***Pour renvoyer toutes les lignes où InternetUse est null, utilisez `WHERE` InternetUse `IS NULL` comme indiqué ici dans cette requête.***
#
# ####**5. Le blanc n'est pas NULL**
#
# + ***Notez qu'il existe une différence entre une valeur vide et une valeur NULL. Parfois, les valeurs manquantes peuvent être formatées comme des blancs. Un espace est composé de deux guillemets simples sans espace entre eux et ne se trouve que dans un champ de texte. Une valeur de ligne vide apparaîtra comme un blanc dans votre requête. Il ne contient pas de valeur, mais il n'apparaîtra pas comme NULL. La meilleure façon de savoir si une colonne contient une valeur vide est de rechercher une colonne où la longueur représentée par LEN est supérieure à 0****
#
# ####**6. Le blanc n'est pas NULL**
#
# + ***Comme une valeur vide est un champ ne contenant rien, vous pouvez exclure les valeurs vides en renvoyant uniquement les lignes où la longueur du champ est supérieure à 0. Pour ce faire, vous pouvez utiliser la fonction LEN avec une parenthèse gauche et une parenthèse droite comme indiqué ici pour ne renvoyer que les colonnes dont la longueur en caractères est supérieure à zéro dans la colonne concernée.***
#
# ####**7. Remplacement des données manquantes par une valeur spécifique à l'aide de ISNULL**
#
# + ***Parfois, vous souhaitez remplacer les valeurs manquantes dans une colonne par une valeur spécifique. Pour ce faire, vous pouvez utiliser la fonction `ISNULL`. Vous passez le nom de la colonne et la valeur à remplacer à `ISNULL` et cela remplacera les valeurs manquantes dans la colonne par la valeur donnée, comme indiqué ici. Notez que vous pouvez remplacer toutes les valeurs manquantes par une seule valeur.***
#
# ####**8. Remplacer les données manquantes par une colonne à l'aide de ISNULL**
#
# + ***Vous pouvez également utiliser `ISNULL` pour remplacer les valeurs manquantes dans une colonne en fonction d'une colonne différente. Ici, nous remplaçons toutes les valeurs manquantes dans TradeGDPPercent par les valeurs de ligne correspondantes de ImportGoodPercent. Le remplacement ne sera effectué que si la valeur dans TradeGDPPercent est nulle.***
#
# ####**9. Substitution des valeurs NULL à l'aide de COALESCE**
#
# + ***Une autre façon de remplacer les valeurs NULL consiste à utiliser l'instruction `COALESCE`. Vous pouvez transmettre plusieurs valeurs à `COALESCE`, et il renverra toujours la première valeur non NULL. Cela revient à utiliser une série d'instructions if-else pour renvoyer la première valeur non manquante.***
#
# ####**10. Instruction SQL utilisant COALESCE**
#
# + ***Voici une requête pour montrer comment COALESCE fonctionne. Pour la première ligne, étant donné que la valeur dans TradeGDPPercent est NULL et que la valeur dans ImportGoodPercent n'est pas NULL, NewPercent reçoit la valeur de la colonne ImportGoodPercent. Pour la deuxième ligne, TradeGDPPercent et ImportGoodPercent sont NULL, donc la colonne NewPercent reçoit la valeur N/A. Enfin, dans la troisième ligne, TradeGDPPercent et ImportGoodPercent ne sont pas NULL, donc la première valeur non NULL, la valeur de la colonne TradeGDPPercent est affectée à NewPercent.***
#
# ####**11. Entraînons-nous !**
#
# + ***Il est temps de mettre cela en pratique***

# %% [markdown]
# ###**EXERCICES**
# ####**Suppression des valeurs manquantes**
#
# + ***Il existe un certain nombre de techniques différentes que vous pouvez utiliser pour corriger les données manquantes dans T-SQL et dans cet exercice, vous vous concentrerez sur le renvoi de lignes avec des valeurs non manquantes. Par exemple, pour renvoyer toutes les lignes avec des valeurs non manquantes SHAPE, vous pouvez utiliser :***
#
#       SELECT *
#       FROM Incidents
#       WHERE Shape IS NOT NULL
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui ne renvoie que les colonnes IncidentDateTime et IncidentStateoù IncidentStateil ne manque pas.

# %%
-- Return the specified columns
SELECT IncidentDateTime, IncidentState
FROM Incidents
-- Exclude all the missing values from IncidentState
WHERE IncidentState IS NOT NULL

# %% [markdown]
# ####**Imputation des valeurs manquantes (I)**
#
# + ***Dans l'exercice précédent, vous avez examiné les valeurs non manquantes de la IncidentStatecolonne. Mais que se passe-t-il si vous souhaitez remplacer les valeurs manquantes par une autre valeur au lieu de les omettre ? Vous pouvez le faire en utilisant la fonction colonne `ISNULL()`. Ici, nous remplaçons toutes les valeurs manquantes dans la Shape en utilisant le mot 'Saucer':***
#
#       SELECT  Shape, ISNULL(Shape, 'Saucer') AS Shape2
#       FROM Incidents
#
# + *Vous pouvez également utiliser `ISNULL()` pour remplacer les valeurs d'une colonne différente au lieu d'un mot spécifié.*
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui ne renvoie que les lignes où IncidentState il manque .
# + Remplacez toutes les valeurs manquantes de la colonne IncidentState par les valeurs de la colonne City et nommez cette nouvelle colonne Location.

# %%
-- Check the IncidentState column for missing values and replace them with the City column
SELECT IncidentState, ISNULL(IncidentState, City) AS Location
FROM Incidents
-- Filter to only return missing values from IncidentState
WHERE IncidentState IS NULL

# %% [markdown]
# ####**Imputation des valeurs manquantes (II)**
#
# + ***Que se passe-t-il si vous souhaitez remplacer les valeurs manquantes d'une colonne par une autre et que vous souhaitez vérifier la colonne de remplacement pour vous assurer qu'elle ne contient aucune valeur manquante ? Pour ce faire, vous devez utiliser la déclaration `COALESCE`.***
#
#       SELECT Shape, City, COALESCE(Shape, City, 'Unknown') as NewShape
#       FROM Incidents
#
#       +----------------+-----------+-------------+
#       | Shape          |  City     |  NewShape   |
#       +----------------+-----------+-------------+
#       | NULL           | Orb       | Orb         |
#       | Triangle       | Toledo    | Triangle    |
#       | NULL           | NULL      | Unknown     |
#       +----------------+-----------+-------------+
#
#
# ####**Instructions**
#
# + Remplacez les valeurs manquantes dans Country par la première valeur non manquante de IncidentState ou City, dans cet ordre. Nommez la nouvelle colonne Location.

# %%
-- Replace missing values
SELECT Country, COALESCE(Country, IncidentState, City) AS Location
FROM Incidents
WHERE Country IS NULL

# %% [markdown]
# ####**1. Regrouper les données avec le cas**
#
# + ***Dans cette leçon, vous travaillerez avec l'instruction `CASE`, qui est couramment utilisée pour évaluer les conditions dans une requête.***
#
# ####**2. Modification des valeurs de colonne avec CASE**
#
# + ***L'instruction CASE nous permet d'évaluer les enregistrements comme une instruction if. Nous pouvons utiliser l'instruction CASE pour vérifier si une colonne contient une valeur et QUAND c'est le cas ALORS nous pouvons remplacer la valeur par une autre valeur de notre choix, SINON la remplacer par toute autre valeur par défaut. Une instruction CASE doit avoir au moins quatre mots-clés : `CASE, WHEN, THEN et END`. Le ELSE est facultatif, mais il est souvent logique de l'inclure.***
#
# ####**3. Modification des valeurs de colonne avec CASE dans T-SQL**
#
# + ***Dans cette requête, si le Continent n'est pas Europe ou Asie, la valeur du champ newContinent sera Other.***
#
# ####**4. Modification des valeurs de colonne avec CASE dans T-SQL**
#
# + ***Examinez comment l'instruction case évalue les valeurs du champ Continent pour déterminer la valeur à y mettre. Dans cette requête, nous créons une nouvelle colonne appelée NewContinent dans laquelle la valeur est Eurasia si la ligne correspondante dans Continent est Europe ou Asia. Si le Continent n'est pas l'Europe ou l'Asie, la valeur dans NewContinent ne change pas.***
#
# ####**5. Utilisation des instructions CASE pour créer des groupes de valeurs**
#
# + ***Une instruction `CASE` est un bon moyen d'organiser les données en groupes plus petits. Il s'agit d'une technique courante pour la science des données. Cet exemple montre comment créer des groupes, souvent appelés groupes, afin que nous puissions évaluer des groupes d'âges plus importants plutôt que des valeurs discrètes. L'instruction Case examine chaque valeur de l'âge et, en fonction de la valeur, remplace l'âge dans la colonne lifeExp par l'un des 5 nombres représentant des groupes d'âges.***
#
# ####**6. Entraînons-nous !**
#
# + ***Il est maintenant temps de s'entraîner avec CASE !***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Utilisation des instructions CASE**
#
# + ***Dans cet exercice, vous allez utiliser une instruction CASE pour créer une nouvelle colonne qui spécifie si le Countryest USA ou International.***
#
# ####**Instructions**
#
# + Créez une nouvelle colonne, SourceCountry, définie à partir de ces cas :
#   + Quand Countryest- 'us'il alors il prend la valeur 'USA'.
#   + Sinon, il prend la valeur 'International'.

# %%
SELECT Country,
       CASE WHEN Country = 'us'  THEN 'USA'
       ELSE 'International'
       END AS SourceCountry
FROM Incidents

# %% [markdown]
# ####**Créer plusieurs groupes avec CASE**
#
# + ***Dans cet exercice, vous allez rédiger une instruction `CASE` pour regrouper les valeurs dans le DurationSecondsen 5 groupes en fonction des plages suivantes :***
#
# ![image.png](data:image/png;base64,...)
#
# ####**Instructions**
#
# + Créez une nouvelle colonne, SecondGroup, qui utilise les valeurs de la colonne DurationSeconds en fonction des plages mentionnées ci-dessus.

# %%
-- Complete the syntax for cutting the duration into different cases
SELECT DurationSeconds,
-- Start with the 2 TSQL keywords, and after the condition a TSQL word and a value
      CASE WHEN  (DurationSeconds <= 120) THEN 1
-- The pattern repeats with the same keyword and after the condition the same word and next value
       WHEN (DurationSeconds > 120 AND DurationSeconds <= 600) THEN  2
-- Use the same syntax here
       WHEN (DurationSeconds > 601 AND DurationSeconds <= 1200) THEN 3
-- Use the same syntax here
       WHEN (DurationSeconds > 1201 AND DurationSeconds <= 5000) THEN 4
-- Specify a value
       ELSE 5
       END AS SecondGroup
FROM Incidents

# %% [markdown]
# ####**1. Comptes et totaux**
#
# + ***Cette leçon développe les agrégations que nous avons abordées dans le premier chapitre en examinant deux fonctions différentes, `SUM et COUNT`. Ces fonctions peuvent être utilisées pour obtenir la somme de toutes les valeurs d'une colonne et compter le nombre d'enregistrements dans une table ou une requête, respectivement.***
#
# ####**2. Examen des totaux avec des décomptes**
#
# + ***En utilisant la fonction `COUNT`, vous pouvez obtenir le nombre total d'enregistrements dans une table. C'est un moyen rapide de déterminer la taille réelle de l'ensemble de données. Vous pouvez passer l'astérisque à `COUNT` pour indiquer que vous souhaitez compter le nombre d'enregistrements dans toute la table.***
#
# ####**3. COMPTER avec DISTINCT**
#
# + ***Si vous souhaitez connaître le nombre de valeurs uniques dans une colonne, vous pouvez utiliser le mot-clé `DISTINCT`. Ce n'est pas le même que le nombre de lignes dans la colonne, sauf si chaque valeur de la colonne répertoriée est unique. Regardons un exemple utilisant la table Incidents du chapitre précédent.***
#
# ####**4. COUNT avec DISTINCT dans T-SQL (I)**
#
# + ***Ici, nous passons `DISTINCT Country à COUNT` pour compter le nombre de pays uniques dans le tableau Incidents. Notez que vous pouvez le faire pour plusieurs colonnes.***
#
# ####**5. COUNT avec DISTINCT dans T-SQL (II)**
#
# + ***Ici, nous calculons les valeurs uniques dans les colonnes Pays et Ville en plaçant le mot clé distinct entre parenthèses après le nombre de mots clés.***
#
# ####**6. Agrégation de comptage**
#
# + ***Comme nous l'avons vu précédemment avec `MIN, AVG et MAX`, vous pouvez utiliser `COUNT` combiné avec `GROUP BY` pour fournir le nombre de groupes de lignes. Pour trier le résultat, vous pouvez utiliser `ORDER BY`. Vous pouvez utiliser le mot-clé `ASC` pour trier les lignes dans l'ordre croissant, qui est la valeur par défaut. Pour trier les lignes par ordre décroissant, utilisez le mot clé `DESC`.***
#
# ####**7. COUNT avec GROUP BY dans T-SQL**
#
# + ***Ici, nous comptons le nombre total de lignes pour chaque pays en utilisant `GROUP BY` et les données ne sont pas triées***
#
# ####**8. COUNT avec GROUP BY et ORDER BY dans T-SQL (I)**
#
# + ***Pour trier les valeurs par ordre croissant de Pays, vous pouvez utiliser `ORDER BY` suivi du mot Pays. Le mot-clé `ASC` est facultatif puisque le tri dans l'ordre croissant est par défaut.***
#
# ####**9. COUNT avec GROUP BY et ORDER BY dans T-SQL (II)**
#
# + ***Pour trier les valeurs par ordre décroissant de pays, utilisez le mot-clé `DESC` dans `ORDER BY`. De cette façon, les États-Unis montrent d'abord***
#
# ####**10. Totaux des colonnes avec SOMME**
#
# + ***Semblable à d'autres fonctions d'agrégation, vous pouvez utiliser la fonction SOMME pour calculer la somme de toutes les valeurs d'une colonne.***
#
# ####**11. Ajout de valeurs de colonne dans T-SQL**
#
# + ***Ici, nous ajoutons des valeurs dans la colonne DurationSeconds à l'aide de la fonction `SUM` pour chaque valeur unique dans Country à l'aide de `GROUP BY`.***
#
# ####**12. Entraînons-nous !**
#
# + ***Essayons maintenant quelques exemples.***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Calcul du total**
# + ***Dans ce chapitre, vous utiliserez les données des expéditions. Le tableau Shipments comporte plusieurs colonnes telles que :***
#
#   + MixDesc: le type de béton
#   + Quantity: la quantité de béton expédiée
#
#
# + *Dans cet exercice, votre objectif est de calculer la quantité totale pour chaque type de béton utilisé.*
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui renverra la somme de la colonne Quantity comme Total pour chaque type de MixDesc.

# %%
-- Write a query that returns an aggregation
SELECT MixDesc, SUM(Quantity) AS Total
FROM Shipments
-- Group by the relevant column
GROUP BY MixDesc

# %% [markdown]
# ####**Compter le nombre de lignes**
#
# + ***Dans cet exercice, vous calculerez le nombre de commandes pour chaque type de béton. Étant donné que chaque ligne représente une commande, il vous suffit de compter le nombre de lignes pour chaque type de MixDesc.***
#
# ####**Instructions**
#
# + Créez une requête qui renvoie le nombre de lignes pour chaque type de MixDesc.

# %%
-- Count the number of rows by MixDesc
SELECT MixDesc, COUNT(MixDesc)
FROM Shipments
GROUP BY MixDesc

# %% [markdown]
# ####**1. Mathématiques avec les dates**
#
# + ***Dans cette leçon, nous allons vous montrer comment effectuer certaines opérations mathématiques courantes avec des dates.***
#
# ####**2. DATEPART**
#
# + ***`DATEPART` est utilisé dans les `fonctions T-SQL DATE` pour spécifier l'unité de mesure, telle que les jours, les mois, les années, les heures, etc. Les abréviations courantes présentées sur la diapositive ici sont traitées comme des mots clés et vous permettent de spécifier quelle partie d'un date ou heure à utiliser dans une fonction de date.***
#
# ####**3. Fonctions de date courantes dans T-SQL**
#
# + ***Dans cette leçon, nous allons vous montrer comment utiliser deux fonctions de date clé dans `T-SQL`, `DATEADD et DATEDIFF`. Vous pouvez utiliser `DATEADD` pour ajouter ou soustraire le `DATEPART`, vous savez les jours, mois, années, dont nous avons parlé précédemment à une valeur `datetime`. Alors que `DATEDIFF` peut être utilisé pour calculer la différence entre deux valeurs `datetime`.***
#
# ####**4. DATEAADD**
#
# + ***`DATEADD` a trois arguments obligatoires. La première est l'unité de mesure, le `DATEPART`, dont nous avons parlé dans une diapositive précédente. Le second est le nombre, un entier à ajouter à la date ou à soustraire pour la date. Et enfin, la date elle-même. Voyons cela en action.***
#
# ####**5. Calcul des dates avec DATEADD (I)**
#
# + ***Supposons que vous souhaitiez connaître la date à 30 jours du 21 juin 2020, vous pouvez utiliser le code indiqué ici. Vous utilisez `DATEADD` avec le premier argument, le `DATEPART` comme DD, puisque vous voulez ajouter un certain nombre de jours. Le deuxième argument est 30, car vous souhaitez ajouter 30 jours, et enfin, le dernier argument est la date à laquelle vous souhaitez ajouter 30 jours, le 21 juin 2020.***
#
# ####**6. Calcul des dates avec DATEADD (II)**
#
# + `DATEADD` vous permet de consulter des dates dans le passé ou dans le futur. Si vous souhaitez revenir en arrière, utilisez un nombre négatif comme deuxième argument de `DATEADD`. Maintenant, si vous voulez connaître la date 30 jours avant le 21 juin 2020, vous pouvez utiliser un code similaire. Cette fois, au lieu d'utiliser plus 30 comme deuxième argument, vous pouvez utiliser moins 30 pour indiquer que vous recherchez une date dans le passé.
#
# ####**7. DATE DIFF**
#
# + ***Semblable à `DATEADD, DATEDIFF` prend trois arguments obligatoires. Le premier argument est le même, datepart, une unité de mesure. Les deuxième et troisième arguments sont respectivement les dates de début et de fin. Voyons `DATEDIFF` en action.***
#
# ####**8. Mathématiques de dates avec DATEDIFF**
# + ***Ici, nous comptons le nombre de jours entre le 22 mai 2020 et le 21 juin 2020 en tant que Différence1, et le 21 juillet 2020 et le 21 juin 2020 en tant que Différence2 en utilisant `DATEDIFF`. Puisque nous voulons connaître le nombre de jours, le premier argument est DD. Notez que si la date de début est inférieure à la date de fin, la différence est positive, alors que si la date de début est supérieure à la date de fin, la différence est une valeur négative pour indiquer que la date est dans le passé.***
#
# ####**9. Entraînons-nous !**
#
# + ***Il est maintenant temps pour vous d'explorer les dates dans T-SQL !***

# %% [markdown]
# ###**EXERCICES**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Correct! DATEDIFF(YYYY, DateOne, DateTwo) fournira la différence entre les deux dates en années.***

# %% [markdown]
# ####**Compter le nombre de jours entre les dates**
#
# + ***Dans cet exercice, vous allez calculer la différence entre la date de commande et la date d'expédition.***
#
# ####**Instructions**
#
# + Écrivez une requête qui renvoie le nombre de jours entre OrderDate et ShipDate

# %%
-- Return the difference in OrderDate and ShipDate
SELECT OrderDate, ShipDate,
       DATEDIFF(DD, OrderDate, ShipDate) AS Duration
FROM Shipments

# %% [markdown]
# ####**Ajouter des jours à une date**
# + ***Dans cet exercice, vous allez calculer la date de livraison approximative d'une commande en fonction de ShipDate.***
#
# ####**Instructions**
#
# + Rédigez une requête qui renvoie la date de livraison approximative sous la forme de cinq jours après le ShipDate.

# %%
-- Return the DeliveryDate as 5 days after the ShipDate
SELECT OrderDate,
       DATEADD(DD, 5, ShipDate) AS DeliveryDate
FROM Shipments

# %% [markdown]
# ####**1. Arrondir et tronquer les nombres**
#
# + ***Lorsque vous effectuez des opérations mathématiques sur des nombres, votre résultat peut avoir 15 décimales alors que vous n'en voulez que 2. Dans cette leçon, nous verrons comment arrondir et tronquer des nombres pour obtenir le nombre de chiffres souhaité avant et après la virgule.***
#
# ####**2. Arrondir les nombres dans T-SQL**
#
# + ***La fonction ARRONDI vous permet d'arrondir les nombres de part et d'autre de la décimale. Il prend deux arguments obligatoires, le nombre à arrondir et la longueur, le nombre de places où le nombre doit être arrondi. Si la longueur spécifiée est négative, les nombres à gauche de la décimale, c'est-à-dire les nombres entiers, sont arrondis. Si le nombre est positif, les chiffres à droite de la virgule, les nombres décimaux sont arrondis.***
#
# ####**3. Arrondir les nombres dans T-SQL**
#
# + ***Cet exemple montre comment arrondir la colonne DurationSeconds pour renvoyer un nombre entier et également arrondir à la première décimale. Dans la colonne RoundToZero, le nombre dans DurationSeconds est arrondi à des nombres entiers en spécifiant le deuxième argument, comme 0. Comme prévu, 121-point-6 est arrondi à 122 et 170-point-3 est arrondi à 170. Dans le Dans la colonne RoundToOne, nous arrondissons les nombres à une décimale en définissant la longueur sur 1. 121-point-64 est arrondi à 121-point-6 et 170-point-39 est arrondi à 170-point-4.***
#
# ####**4. Arrondi à gauche de la décimale**
#
# + ***De même, nous pouvons également arrondir les nombres à gauche de la décimale. Ici, nous arrondissons à nouveau la colonne DurationSeconds deux fois. Tout d'abord, nous l'arrondissons à la dizaine la plus proche en passant moins un comme deuxième argument. Étant donné que 1 et 0 sont les premiers chiffres à gauche de la décimale dans 121-virgule-6 et 170-virgule-3, ces nombres sont arrondis à 120 et 170, respectivement. Cependant, puisque 6 est le premier chiffre à gauche de la décimale dans 336-point-0, il est arrondi à 340. Ensuite, nous arrondissons DurationSeconds à la centaine la plus proche en passant moins deux comme deuxième argument. Cette fois, puisque 2 et 3 sont les deuxièmes chiffres à gauche de la décimale dans 121-point-6 et 336-point-0, ils sont arrondis à 100 et 300, respectivement. Cependant, comme 7 est le deuxième chiffre à gauche de la décimale dans 170 virgule 3, il est arrondi à 200.***
#
# ####**5. Tronquer les nombres**
#
# + ***Parfois, vous souhaitez simplement tronquer des valeurs au lieu d'arrondir vers le haut ou vers le bas. Par exemple, le résultat de la troncation de 17-point-85 à un nombre entier serait 17.***
#
# ####**6. Tronquer avec ROUND()**
#
# + ***L'ajout du troisième argument à la fonction `round` tronquera la valeur au lieu de l'arrondir.***
#
# ####**7. Tronquer dans T-SQL**
#
# + ***Cet exemple montre la différence entre arrondir et tronquer. Étant donné que 0 est spécifié comme deuxième argument dans la fonction `ROUND`, toutes les décimales seront arrondies au nombre entier le plus proche. Lorsque la valeur est arrondie, le nombre à droite de la décimale importe. Lors de la troncation, les nombres après la virgule sont ignorés. Vous pouvez voir dans l'exemple que les résultats de la troncation et de l'arrondi sont différents puisque la troncation renvoie les nombres à gauche de la décimale quoi qu'il arrive.***
#
# ####**8. Entraînons-nous !**
#
# + ***Il est temps de s'entraîner un peu plus.***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Arrondir les nombres**
#
# + ***Parfois, vous ne vous souciez que du montant total en dollars et souhaitez ignorer les valeurs décimales du coût. Dans cet exercice, vous arrondirez le coût au dollar près.***
#
# ####**Instructions**
#
# + Écrivez une requête SQL pour arrondir les valeurs de la colonne Cost au nombre entier le plus proche.

# %%
-- Round Cost to the nearest dollar
SELECT Cost,
       ROUND(Cost, 0) AS RoundedCost
FROM Shipments

# %% [markdown]
# ####**Tronquer des nombres**
# + ***Étant donné que l'arrondi peut parfois être trompeur, c'est-à-dire que `16,8 $` devient `17 $` tandis que `16,4 $` reste `16 $` , vous pouvez tronquer les valeurs après la décimale au lieu de les arrondir. Lorsque vous tronquez les nombres, `16,8 $` et `16,4 $` restent `16 $` . Dans cet exercice, vous allez faire exactement cela, tronquer la Costcolonne à un nombre entier.***
#
# ####**Instructions**
#
# + ***Écrivez une requête SQL pour tronquer les valeurs de la Costcolonne au nombre entier le plus proche.***

# %%
-- Truncate cost to whole number
SELECT Cost,
       ROUND(Cost, 0, 1) AS TruncateCost
FROM Shipments

# %% [markdown]
# ####**1. Plus de fonctions mathématiques**
#
# + ***Lorsque vous travaillez avec des données numériques, vous pouvez appliquer plusieurs transformations, telles que la valeur absolue, le carré, la racine carrée ou même l'application d'une transformation logarithmique pour obtenir de meilleurs résultats. Ces types d'ajustements de données sont très faciles à faire avec T-SQL et seront au centre de cette leçon.***
#
# ####**2. Valeur absolue**
#
# + ***Il y a des moments où vous ne vous souciez pas de savoir si la valeur est positive ou négative, vous n'êtes intéressé que par la valeur du nombre. Lorsque c'est le cas, vous pouvez utiliser ABS pour renvoyer uniquement des valeurs non négatives.***
#
# ####**3. Utiliser ABS dans T-SQL (I)**
#
# + ***Les fonctions mathématiques telles que celles présentées dans cette leçon sont différentes des agrégations. Ces fonctions sont appliquées à chaque élément d'une colonne et rien n'est résumé.***
#
# ####**4. Utiliser ABS dans T-SQL (II)**
#
# + ***Dans cet exemple, nous renvoyons la valeur absolue de la colonne DurationSeconds. Notez que les valeurs de la colonne DurationSeconds une fois la valeur absolue appliquée sont toujours positives.***
#
# ####**5. Carrés et racines carrées en T-SQL**
#
# + ***Pour trouver la racine carrée d'un nombre, vous pouvez utiliser la fonction SQRT, et pour trouver le carré d'un nombre, vous pouvez utiliser la fonction SQUARE comme indiqué ici.***
#
# ####**6. Journaux**
#
# + ***La transformation logarithmique des colonnes numériques est une pratique courante. Par exemple, si vous souhaitez analyser le prix et que les données semblent asymétriques, vous pouvez utiliser la valeur logarithmique pour déplacer l'inclinaison vers une courbe en cloche plus normalisée. Vous pouvez utiliser la fonction `LOG` à cette fin. Par défaut, il renvoie le logarithme népérien.***
#
# ####**7. Calcul des journaux dans T-SQL**
#
# + ***Nous montrons ici comment calculer le log base 10 de la colonne DurationSeconds. Le premier argument de `LOG` est le nom de la colonne et le deuxième argument est la base 10.***
#
# ####**8. Journal de 0**
#
# + ***Étant donné que le journal 0 n'est pas défini, vous obtiendrez une erreur si vous essayez de prendre le journal de 0. Assurez-vous donc que vous appliquez `LOG` uniquement aux valeurs non nulles de votre colonne.***
#
# ####**9. Entraînons-nous !**
#
# + ***Maintenant c'est ton tour.***

# %% [markdown]
# ###**EXERCICES**
# ####**Calcul de la valeur absolue**
# + ***Le tableau Shipments contient des données erronées. Il y avait un problème avec la balance et les poids s'affichent sous forme de nombres négatifs. Dans cet exercice, vous allez écrire une requête pour convertir toutes les pondérations négatives en pondérations positives.***
#
# ####**Instructions**
#
# + Écrivez une requête qui convertit toutes les valeurs négatives de la colonne DeliveryWeight en valeurs positives.

# %%
-- Return the absolute value of DeliveryWeight
SELECT DeliveryWeight,
       ABS(DeliveryWeight) AS AbsoluteValue
FROM Shipments

# %% [markdown]
# ####**Calcul des carrés et des racines carrées**
# + ***Il est temps pour vous de vous entraîner à calculer les carrés et les racines carrées des colonnes.***
#
# ####**Instructions**
#
# + Écrivez une requête qui calcule le carré et la racine carrée de la colonne WeightValue.

# %%
-- Return the square and square root of WeightValue
SELECT WeightValue,
       SQUARE(WeightValue) AS WeightSquare,
       SQRT(WeightValue) AS WeightSqrt
FROM Shipments

# %% [markdown]
# ####**1. Boucles WHILE**
#
# + ***Le traitement des données à l'aide de boucles est une technique courante dans de nombreux langages de programmation. Dans cette leçon, nous allons revoir la modification des données en créant des variables et en les utilisant dans une boucle `WHILE`.***
#
# ####**2. Utiliser des variables dans T-SQL**
#
#
# + ***La création de variables dans vos requêtes `T-SQL` est utile dans plusieurs cas. Dans `T-SQL`, vous créez des variables à l'aide du mot-clé DECLARE. Le premier caractère du nom de la variable doit commencer par le signe arobase et vous devez affecter un type de données valide à la variable.***
#
# ####**3. Types de données variables dans T-SQL**
#
# + ***T-SQL prend en charge plusieurs types de types de données. Les plus courants sont `VARCHAR, INT et DECIMAL`. `VARCHAR` peut être utilisé pour stocker des chaînes de longueur variable où n est la longueur de la chaîne en octets. `INT` peut être utilisé pour stocker des entiers positifs et négatifs dans la plage de 2 milliards. `DECIMAL` peut être utilisé pour stocker des nombres réels. $p$ est le nombre total de chiffres qui seront stockés de part et d'autre de la décimale. L'argument, $s$, spécifie le nombre de chiffres à stocker à droite de la décimale. `DECIMAL et NUMERIC` sont synonymes et fonctionnent exactement de la même manière, vous pouvez donc utiliser l'un ou l'autre pour stocker des nombres avec des décimales.***
#
# ####**4. Déclarer des variables dans T-SQL**
#
# + ***Comme mentionné précédemment, vous devez utiliser le mot clé `DECLARE` pour déclarer des variables dans T-SQL. Ici, nous déclarons la variable Snack et affectons le type de données `VARCHAR` avec une longueur de 10. Notez que le nom de la variable commence par le signe arobase.***
#
# ####**5. Affectation de valeurs aux variables**
#
# + ***Il existe deux méthodes différentes pour attribuer une valeur à une variable. Vous pouvez soit utiliser le mot-clé réservé `SET`, soit utiliser `SELECT` pour affecter une valeur à une variable. Lorsque vous affectez une valeur à une variable à l'aide de `SET ou SELECT`, aucun résultat n'est affiché. Pour voir la valeur d'une variable, vous devez écrire une instruction SELECT distincte pour renvoyer la valeur, comme indiqué ici.***
#
# ####**6. Boucles WHILE**
#
# + ***Tandis que les boucles dans T-SQL fonctionnent de la même manière que dans n'importe quel autre langage de programmation. Ils doivent commencer par le mot clé `WHILE` et une sorte de condition, telle que $x$ inférieur à 5, qui sera évaluée à chaque exécution de la boucle. Le mot-clé suivant est `BEGIN`, qui est utilisé pour indiquer le début de la boucle. Le code que vous voulez exécuter commence ici et continue jusqu'au mot clé `END`. Si vous souhaitez sortir de la boucle au milieu, utilisez le mot-clé `BREAK`. Si vous voulez continuer la boucle, utilisez le mot-clé `CONTINUE`.***
#
# 7. Boucle WHILE dans T-SQL (I)
# 02:22 - 03:08
# + ***Ici, nous voyons la syntaxe standard pour une instruction `while`. Tout d'abord, nous déclarons et définissons la variable `ctr` sur 1. Nous spécifions ensuite le mot-clé `WHILE` avec la condition `ctr` inférieure à 10. Cette condition nous indique que la boucle WHILE s'exécutera tant que la valeur de `ctr` sera inférieure à 10. Après cela , on écrit le code à exécuter entre les mots clés `BEGIN et END`. Nous incrémentons la valeur de ctr de 1 en utilisant le mot clé `SET`. Dès que la valeur de ctr atteint 10 à l'intérieur de la boucle, la boucle s'arrête car la condition de l'instruction `while ctr` doit être inférieure à 10, est évaluée à false. Une fois la boucle terminée, nous imprimons la valeur dans la variable ctr.***
#
# ####**8. Boucle WHILE dans T-SQL (II)**
#
# + ***ans cet exemple, la commande `BREAK sort` de la boucle avant la fin de la boucle. Si vous souhaitez quitter la boucle WHILE lorsque ctr est égal à 4, vous pouvez écrire une vérification conditionnelle à l'intérieur de la boucle WHILE. La partie où vous incrémentez le compteur est la même qu'avant. Mais maintenant, au lieu de terminer la boucle, vous écrivez une instruction `IF` pour vérifier si `ctr` est égal à 4 et utilisez le mot-clé `BREAK` pour quitter la boucle si c'est vrai. Ce code ne s'exécutera que 3 fois, puis sortira de la boucle. Si vous imprimez la valeur de ctr à la fin de cette boucle, vous remarquerez qu'elle est égale à 4.***
#
# ####**9. Entraînons-nous !**
#
# + ***C'est maintenant à votre tour de pratiquer les boucles WHILE dans T-SQL.***

# %% [markdown]
# ###****
#
# ####**Créer et utiliser des variables**
#
# + ***Dans T-SQL, pour créer une variable, vous utilisez l'instruction `DECLARE`. Les variables doivent avoir un signe arobase ( @) comme premier caractère. Comme la plupart des choses dans T-SQL, les variables ne sont pas sensibles à la casse. Pour attribuer une valeur à une variable, vous pouvez soit utiliser le mot clé `SET`ou une instruction `SELECT`, puis le nom de la variable suivi d'un signe égal et d'une valeur.***
#
# ####**Consignes**
# + Créez une variable entière nommée counter.
# + Attribuez la valeur 20 à cette variable.
# + Incrémentez la variable counterde 1 et réaffectez-la à counter.

# %%
-- Declare the variable (a SQL Command, the var name, the datatype)
DECLARE @counter INT

-- Set the counter to 20
SET @counter = 20

-- Select and increment the counter by one
SELECT @counter = @counter + 1

-- Print the variable
SELECT @counter

# %% [markdown]
# ####**Création d'une boucle WHILE**
# + ***Dans cet exercice, vous utiliserez la variable que vous avez créée dans l'exercice précédent pour écrire une boucle `WHILE`. Rappelons cette structure :***
#
#       WHILE some_condition
#
#       BEGIN
#           -- Perform some operation here
#       END
#
#
# ####**Instructions**
#
# + Écrivez une boucle `WHILE` qui incrémente counterde 1 jusqu'à ce qu'elle countersoit inférieure à 30.

# %%
DECLARE @counter INT
SET @counter = 20

-- Create a loop
WHILE @counter < 30

-- Loop code starting point
BEGIN
	SELECT @counter = @counter + 1
-- Loop finish
END

-- Check the value of the variable
SELECT @counter

# %% [markdown]
# ####**1. Tableaux dérivés**
#
# + ***Les tables dérivées sont un autre nom pour une requête agissant comme une table et sont couramment utilisées pour effectuer des agrégations dans T-SQL. Voyons comment les créer.***
#
# ####**2. Que sont les tables dérivées ?**
#
# + ***Quand une requête n'est-elle pas une requête ? Lorsqu'il s'agit d'une table dérivée. Vous pouvez utiliser des tables dérivées lorsque vous souhaitez décomposer une requête complexe en étapes plus petites. Les tables dérivées sont répertoriées dans la section `FROM` de la requête comme des tables et constituent une excellente solution si vous souhaitez créer des calculs intermédiaires qui doivent être utilisés dans une requête plus large. Construisons une table dérivée dans T-SQL.***
#
# ####**3. Tables dérivées dans T-SQL**
#
# + ***Cette requête renverra toutes les lignes de la table Kidney pour les personnes d'âge moyen. La table dérivée se trouve après la jointure et peut inclure n'importe quelle table de la base de données. Ici, la requête calculera une seule valeur, ce qui signifie que la table dérivée ne contiendra qu'une seule valeur, l'âge moyen dans les données. La table dérivée est jointe à la table Kidney, ce qui signifie que les seuls enregistrements renvoyés seront pour les enregistrements de personnes qui ont l'âge moyen. Remarquez comment les deux tables sont aliasées et pas seulement la table dérivée ? Il est courant de le faire afin que vous n'ayez pas à taper le nom de la table chaque fois que vous avez besoin de référencer des valeurs dans cette table.***
#
# ####**4. Entraînons-nous !**
#
# + ***Essayons maintenant quelques exemples utilisant des requêtes dérivées.***

# %% [markdown]
# ####**Requêtes avec tables dérivées (I)**
#
# + ***Cette leçon porte sur les tables dérivées . Vous pouvez utiliser des tables dérivées lorsque vous souhaitez décomposer une requête complexe en étapes plus petites. Une table dérivée est une requête utilisée à la place d'une table. Les tables dérivées sont une excellente solution si vous souhaitez créer des calculs intermédiaires qui doivent être utilisés dans une requête plus large.***
#
# + *Dans cet exercice, vous calculerez la valeur maximale de la glycémie pour chaque enregistrement par âge.*
#
# ####**Instructions**
#
# + Retour MaxGlucose de la table dérivée.
# + Joignez la table dérivée à la requête principale sur Age.

# %%
SELECT a.RecordId, a.Age, a.BloodGlucoseRandom,
-- Select maximum glucose value (use colname from derived table)
       b.MaxGlucose
FROM Kidney a
-- Join to derived table
JOIN (SELECT Age, MAX(BloodGlucoseRandom) AS MaxGlucose FROM Kidney GROUP BY Age) b
-- Join on Age
ON a.Age = b.Age

# %% [markdown]
# ####**Requêtes avec tables dérivées (II)**
#
# + ***Dans cet exercice, vous allez créer une table dérivée pour renvoyer tous les enregistrements patient avec le plus élevé BloodPressureà leur niveau Age.`***``
#
# ```
#
# ####**Instructions**
#
# + Créer une table dérivée
# + retour Age et MaxBloodPressure; ce dernier est le maximum de BloodPressure.
# + est tiré du kidneytableau.
# + est regroupé par Age.
# + Joindre la table dérivée à la requête principale sur
# pression artérielle égale à la pression artérielle max.
# âge.

# %%
SELECT *
FROM Kidney a
-- Create derived table: select age, max blood pressure from kidney grouped by age
JOIN (SELECT Age, MAX(BloodPressure)AS MaxBloodPressure FROM Kidney  GROUP BY Age) b
-- JOIN on BloodPressure equal to MaxBloodPressure
ON a.BloodPressure = b.MaxBloodPressure
-- Join on Age
AND a.Age = b.Age

# %% [markdown]
# ####**1. Expressions de table courantes**
#
# + ***`Les expressions de table communes`, communément appelées `CTE`, sont un autre type de table dérivée. Ils sont peu différents car ils peuvent être utilisés plusieurs fois dans une requête et sont définis comme une table.***
#
# ####**2. Syntaxe CTE**
#
# + ***Un `CTE` agit un peu comme une table qui est définie avant de l'utiliser. Une fois que vous avez défini le `CTE`, vous pouvez l'utiliser dans la requête suivant le CTE, comme s'il s'agissait d'une table. Lors de la création d'un CTE, vous spécifiez le mot-clé WITH, suivi du nom du CTE, puis d'une liste des colonnes qu'il contient. Ensuite, spécifiez le mot-clé AS suivi de la requête utilisée pour créer un CTE entre parenthèses. Les noms de colonne doivent correspondre aux colonnes de la requête. Regardons un exemple réel maintenant.***
#
# ####**3. CTE dans T-SQL**
#
# + ***Ce `CTE` est nommé BloodPressureAge et contient deux colonnes, Age et MaxBloodPressure. Une fois les colonnes répertoriées, le mot clé AS est utilisé et la requête pour créer le `CTE` est spécifiée entre parenthèses. Cette première requête contient l'âge et la tension artérielle max regroupés par âge. Notez que la requête et la définition `CTE` contiennent toutes deux deux colonnes. Une fois le `CTE` défini, il peut être utilisé comme n'importe quel tableau dans la requête en dessous. La requête après le `CTE` utilise le `CTE` BloodPressureAge comme s'il s'agissait d'un tableau. La requête associe la pression artérielleAged au `CTE` et affiche à la fois la pression artérielle minimale et maximale en fonction de l'âge.***
#
# ####**4. Entraînons-nous !**
#
# + ***Essayons maintenant quelques exemples de CTE.***

# %% [markdown]
# ###**EXERCICES**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Tu te débrouilles bien! Un CTE est un type de table temporaire.***

# %% [markdown]
# ####**Création de CTE (I)**
#
# + ***`Une expression de table commune ou CTE` est utilisée pour créer une table qui peut ensuite être utilisée avec une requête. Pour créer un `CTE`, vous utiliserez toujours le mot-clé `WITH` suivi du nom du `CTE` et du nom des colonnes que contient le `CTE`. `Le CTE` inclura également la définition du tableau inclus dans le `AS()`.**
#
# + *Dans cet exercice, vous utiliserez un `CTE` pour renvoyer tous les âges avec le maximum BloodGlucose dans le tableau Random.*
#
# ####**Instructions**
#
# + Créez un CTE BloodGlucoseRandom qui renvoie une colonne ( MaxGlucose) contenant le maximum BloodGlucoseRandomdans le tableau.
# + Joignez le CTE à la table principale (Kidney) sur BloodGlucoseRandom et MaxGlucose.

# %%
-- Specify the keyowrds to create the CTE
WITH BloodGlucoseRandom (MaxGlucose)
AS (SELECT MAX(BloodGlucoseRandom) AS MaxGlucose FROM Kidney)

SELECT a.Age, b.MaxGlucose
FROM Kidney a
-- Join the CTE on blood glucose equal to max blood glucose
JOIN BloodGlucoseRandom b
ON a.BloodGlucoseRandom = b.MaxGlucose

# %% [markdown]
# ####**Création de CTE (II)**
#
# + ***Dans cet exercice, vous allez utiliser un CTE pour renvoyer toutes les informations concernant le(s) patient(s) avec le maximum BloodPressure.***
#
# ####**Instructions**
#
# + Créez un CTE BloodPressure qui renvoie une colonne ( MaxBloodPressure) contenant le maximum BloodPressuredans le tableau.
# + Joignez ce CTE (en utilisant un alias b) à la table principale ( Kidney) pour renvoyer des informations sur les patients avec le maximum BloodPressure.

# %%
-- Create the CTE
WITH BloodPressure(MaxBloodPressure)
AS (SELECT MAX(BloodPressure) AS MaxBloodPressure FROM Kidney)

SELECT *
FROM Kidney a
-- Join the CTE
JOIN BloodPressure b
ON a.BloodPressure = b.MaxBloodPressure

# %% [markdown]
# ####**1. Fonctions de la fenêtre**
#
# + ***Dans cette leçon, nous présenterons les fonctions de fenêtrage, qui permettent de créer et d'analyser des groupes de données. Avec les fonctions de fenêtrage, vous pouvez regarder la ligne actuelle, la ligne suivante et la ligne précédente en même temps de manière très efficace.***
#
# ####**2. Appliquer des fenêtres aux données d'un tableau**
#
# + ***À l'aide des fonctions de fenêtrage, les données d'une table sont traitées comme un groupe, ce qui permet d'évaluer chaque groupe séparément. Dans l'exemple présenté ici, les données sont divisées en fenêtres basées sur la colonne SalesYear.***
#
# ####**3. Regroupement de données dans T-SQL**
#
# + ***Cette requête montre comment vous pouvez renvoyer toutes les données pour 2011. À l'aide des fonctions de fenêtrage, vous pouvez créer une requête pour renvoyer des valeurs par année sans savoir quelles sont les valeurs pour l'année.***
#
# ####**4. Syntaxe de fenêtre dans T-SQL**
#
# + ***Une fenêtre est créée à l'aide de la clause `OVER`. Ensuite, à l'intérieur des parenthèses, vous pouvez fournir les mots clés réservés facultatifs `PARTITION BY` pour créer la limite de la fenêtre en fonction des colonnes spécifiées. Si vous n'incluez pas `PARTITION BY`, le cadre est créé pour toute la table. Pour organiser la sortie, vous pouvez utiliser `ORDER BY`. Après avoir créé la fenêtre, vous pouvez ajouter de nouvelles fonctions.***
#
# ####**5. Fonctions de fenêtre (SOMME)**
#
# + ***Ici, nous partitionnons la table par SalesYear et utilisons la fonction de fenêtrage `SUM` pour additionner chaque ligne de la colonne CurrentQuota dans la fenêtre afin de fournir un total pour toute la fenêtre dans la colonne YearTotal. Lorsque l'année change, la valeur de la colonne YearTotal change pour afficher le total de l'année suivante, car la fenêtre est partitionnée par SalesYear. Nous ne montrons pas toutes les lignes pour 2012 ici, juste une ligne pour 2012.***
#
# ####**6. Fonctions de fenêtre (COUNT)**
#
# + ***En plus d'utiliser `SUM`, vous pouvez également utiliser d'autres agrégations dans les fonctions de fenêtrage. Ici, nous avons créé la même fenêtre que la dernière diapositive, mais nous utilisons `COUNT au lieu de SUM`. Tout comme pour `SUM`, la valeur de la colonne QuotaPerYear recommence lorsque l'année change.***
#
# ####**7. Entraînons-nous !**
#
# + ***Il est temps pour vous de pratiquer les fonctions de fenêtrage !***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Fonctions de fenêtre avec agrégations (I)**
# + ***Pour vous familiariser avec les fonctions de la fenêtre, vous travaillerez avec le Orderstableau de ce chapitre. Rappelez-vous qu'en utilisant `OVER()`, vous pouvez créer une fenêtre pour toute la table. Pour créer des partitions à l'aide d'une colonne spécifique, vous devez utiliser `OVER()` avec `PARTITION BY`.***
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui renvoie la somme de OrderPrice en créant des partitions pour chaque TerritoryName.

# %%
SELECT OrderID, TerritoryName,
       -- Total price for each partition
       SUM(OrderPrice)
       -- Create the window and partitions
       OVER(PARTITION BY TerritoryName) AS TotalPrice
FROM Orders

# %% [markdown]
# ####**Fonctions de fenêtre avec agrégations (II)**
#
# + ***Dans le dernier exercice, vous avez calculé la somme de toutes les commandes pour chaque territoire. Dans cet exercice, vous calculerez le nombre de commandes dans chaque territoire.***
#
# ####**Instructions**
#
# + Comptez le nombre de lignes dans chaque partition.
# + Partitionnez la table par TerritoryName.

# %%
SELECT OrderID, TerritoryName,
       -- Number of rows per partition
       COUNT(OrderPrice)
       -- Create the window and partitions
       OVER(PARTITION BY TerritoryName) AS TotalOrders
FROM Orders

# %% [markdown]
# ####**1. Fonctions de fenêtre communes**
#
# + ***Dans la leçon précédente, nous avons examiné l'utilisation des agrégations que nous avions examinées précédemment, mais il existe également des fonctions spécifiques qui ont été créées expressément pour être utilisées avec les fonctions Windows. Cette leçon couvre quatre des fonctions de fenêtrage les plus couramment utilisées, `FIRST_VALUE, LAST_VALUE, LEAD et LAG`.***
#
# ####**2. FIRST_VALUE() et LAST_VALUE()**
#
# + ***`FIRST_VALUE et LAST_VALUE` renvoient respectivement la première et la dernière valeurs de chaque fenêtre. Ainsi, chacun d'eux renvoie une valeur pour toute la fenêtre. Parce que vous essayez de trouver un enregistrement spécifique dans une fenêtre, la position des enregistrements dans la fenêtre doit être spécifiée à l'aide de la commande ORDER BY. La première valeur de chaque fenêtre affichée ici est 28 000, 140 000 et 367 000.***
#
# ####**3. FIRST_VALUE() et LAST_VALUE() dans T-SQL**
#
# + ***Voici le code utilisé pour créer des fenêtres comme indiqué sur la diapositive précédente et les utiliser pour sélectionner les première et dernière valeurs de CurrentQuota pour chaque fenêtre. La fenêtre est triée en fonction des valeurs du champ ModifiedDate. La commande `ORDER BY` est requise dans l'instruction `OVER` après le partitionnement de la colonne car les valeurs d'ordre apparaissent dans la fenêtre et déterminent la première ou la dernière valeur. Dans cette requête, les données sont triées par ModifiedDate à l'aide de `ORDER BY`.***
#
# ####**4. Résultats**
#
# + ***Dans cette diapositive de résultats, les valeurs de StartQuota et EndQuota sont les mêmes sur toutes les lignes d'une fenêtre. Voyons maintenant comment interroger les lignes adjacentes.***
#
# ####**5. Obtenir la valeur suivante avec LEAD()**
#
# + ***À l'aide de `LEAD`, vous pouvez comparer la valeur de la ligne actuelle à la valeur de la ligne suivante dans la fenêtre. Pour la dernière ligne de la fenêtre, la valeur `LEAD` sera toujours NULL, car il n'y a pas de valeur suivante dans la fenêtre. Regardez les valeurs dans cet exemple. La fenêtre est représentée par une case verte qui inclut toutes les lignes de SalesYear 2011 car la fenêtre est partitionnée par SalesYear. La valeur de la colonne NextQuota dans chaque ligne provient de la valeur CurrentQuota dans la ligne suivante. Étant donné que `LEAD` évalue uniquement dans la fenêtre, la dernière ligne de NextQuota dans chaque fenêtre est `NULL` car il n'y a pas de valeur suivante. Étant donné que `LEAD` obtient toujours la valeur suivante, il est important d'utiliser `ORDER BY` pour déterminer correctement l'ordre de toutes les lignes dans la fenêtre.***
#
# ####**6. LEAD() dans T-SQL**
#
# + ***Voici le code T-SQL utilisant `LEAD`. Remarquez que `LEAD` est en dehors de la fenêtre et que la colonne CurrentQuota lui est transmise. La fenêtre suit avec le mot-clé `OVER` et est partitionnée par la colonne SalesYear. `LEAD` nécessite la clause `ORDER BY` pour trier les valeurs dans la fenêtre, qui est triée par ModifiedDate. Notez que chaque fenêtre se termine par un `NULL`.***
#
# ####**7. Obtenir la valeur précédente avec LAG()**
#
# + ***De même, vous pouvez utiliser `LAGè  pour comparer la valeur de la ligne actuelle à la valeur de la ligne précédente dans la fenêtre. Pour la première ligne de la fenêtre, la valeur `LAG` sera toujours `NULL`, car il n'y a pas de valeur précédente dans la fenêtre. Regardez les valeurs dans cet exemple. La fenêtre est représentée par une case verte qui inclut toutes les lignes de SalesYear 2011 car la fenêtre est partitionnée par SalesYear. La valeur de la colonne PreviousQuota de chaque ligne provient de la valeur CurrentQuota de la ligne précédente. Étant donné que LAG n'évalue que dans la fenêtre, la première ligne de PreviousQuota dans chaque fenêtre est NULL car il n'y a pas de valeur précédente. Étant donné que LAG obtient toujours la valeur précédente, il est important d'utiliser ORDER BY pour déterminer correctement l'ordre de toutes les lignes dans la fenêtre.***
#
# ####**8. LAG() dans T-SQL**
#
# + ***Voici le code T-SQL utilisant `LAG`. `LAG` est également en dehors de la fenêtre et la colonne CurrentQuota lui est transmise. La fenêtre suit avec le mot-clé `OVER` et est partitionnée par la colonne SalesYear. Semblable à `LEAD, LAG` nécessite également la clause `ORDER BY` pour ordonner les valeurs dans la fenêtre, qui est ordonnée par ModifiedDate. Notez que chaque fenêtre commence par un `NULL`.***
#
# ####**9. Pratiquons !**
#
# + ***Allez-y et entraînez-vous à utiliser ces fonctions de fenêtre courantes.***

# %% [markdown]
# ###**EXERCICES**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Correct! Bien que vous puissiez l'utiliser `ORDER BY` dans des agrégations standard, cela n'est pas obligatoire.***

# %% [markdown]
# ####**Première valeur dans une fenêtre**
# + ***Supposons que vous souhaitiez déterminer le premier OrderDatede chaque territoire ou le dernier. Comment feriez-vous cela? Vous pouvez utiliser les fonctions de fenêtre `FIRST_VALUE() et LAST_VALUE()`, respectivement ! Voici les étapes :***
#
#   + Tout d'abord, créez des partitions pour chaque territoire
#   + Ensuite, commandez parOrderDate
#   + Enfin, utilisez les fonctions `FIRST_VALUE()et/ou LAST_VALUE()` selon vos besoins
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui renvoie la première OrderDate en créant des partitions pour chaque fichier TerritoryName.

# %%
SELECT TerritoryName, OrderDate,
       -- Select the first value in each partition
       FIRST_VALUE(OrderDate)
       -- Create the partitions and arrange the rows
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS FirstOrder
FROM Orders

# %% [markdown]
# ####**Valeurs précédentes et suivantes**
# + ***Que faire si vous souhaitez décaler les valeurs d'une colonne d'une ligne vers le haut ou vers le bas ? Vous pouvez suivre exactement les mêmes étapes que dans l'exercice précédent, mais avec deux nouvelles fonctions, , `LEAD()` pour la valeur suivante, et `LAG()`, pour la valeur précédente. Alors vous suivez ces étapes :***
#
#   + Tout d'abord, créez des partitions
#   + Ensuite, triez par une certaine colonne
#   + Enfin, utilisez les fonctions `LEAD()et/ou LAG()` selon vos besoins
#
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui, pour chaque territoire :
#   + Décale les valeurs d'une ligne OrderDate  vers le bas. Appelez cette colonne PreviousOrder.
#   + Déplace les valeurs d'une ligne OrderDatevers le haut. Appelez cette colonne NextOrder. Vous devrez PARTITIONNER PAR le territoire

# %%
SELECT TerritoryName, OrderDate,
       -- Specify the previous OrderDate in the window
       LAG(OrderDate)
       -- Over the window, partition by territory & order by order date
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS PreviousOrder,
       -- Specify the next OrderDate in the window
       LEAD(OrderDate)
       -- Create the partitions and arrange the rows
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS NextOrder
FROM Orders

# %% [markdown]
# ####**1. Augmentation de la complexité des fenêtres**
#
# + ***Dans cette leçon, nous allons examiner les fonctions que nous avons examinées précédemment et appliquer de nouveaux concepts pour obtenir des résultats différents.***
#
# ####**2. Examen des agrégations**
#
# + ***Vous souvenez-vous de ce code de la première vidéo du chapitre ? Ici, nous calculons un total pour chaque fenêtre ou chaque SalesYear et il n'y a pas `ORDER BY` car contrairement à des fonctions de fenêtre spécifiques comme `LEAD, ORDER BY` n'est pas nécessaire.***
#
# ####**3. Ajouter ORDER BY à une agrégation**
#
# + ***Si vous prenez la même requête et ajoutez la clause `ORDER BY` SalesPerson dans la fenêtre, les résultats changent. Désormais, les valeurs de la colonne CurrentQuota sont totalisées par SalesPerson et SalesYear. Dans SalesYear, chaque fois que SalesPerson change, le total change.***
#
# ####**4. Création d'un total cumulé avec ORDER BY**
#
# + ***Chaque fois que vous commandez par une colonne différente, les résultats changent. Dans cette requête, le ModifiedDate est différent pour chaque ligne, et le résultat est donc un total cumulé. Pour créer un total cumulé, ORDRE PAR la colonne qui est différente pour chaque ligne de la fenêtre.***
#
# ####**5. Ajouter des numéros de ligne**
#
# + ***Dans certaines situations, vous souhaitez attribuer des numéros de ligne à chaque ligne d'une fenêtre. Vous pouvez le faire en utilisant la fonction `ROW_NUMBER`. Semblable à `LEAD et LAG`, le mot clé `ORDER_BY` est requis lors de l'utilisation de `ROW_NUMBER`.***
#
# ####**6. Ajout de numéros de ligne dans T-SQL**
#
# + ***Ici, nous utilisons le `ROW_NUMBER` pour attribuer un numéro de ligne à chaque ligne de la fenêtre. La fenêtre est partitionnée par SalesPerson et ordonnée par SalesYear.***
#
# ####**7. Entraînons-nous !**
#
# + ***Super! Allez-y, créez des totaux cumulés et attribuez des numéros de ligne.***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Création de totaux cumulés**
#
# + ***Vous n'êtes généralement pas obligé d'utiliser `ORDER BY` lorsque vous utilisez des agrégations, mais si vous souhaitez créer des totaux cumulés, vous devez organiser vos lignes ! Dans cet exercice, vous allez créer un total cumulé de OrderPrice.***
#
# ####**Instructions**
#
# + Créez la fenêtre, partitionnez par TerritoryName et triez par OrderDate pour calculer un total cumulé de OrderPrice.

# %%
SELECT TerritoryName, OrderDate,
       -- Create a running total
        SUM(OrderPrice)
       -- Create the partitions and arrange the rows
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS TerritoryTotal
FROM Orders

# %% [markdown]
# ####**Attribuer des numéros de ligne**
#
# + ***Les enregistrements dans T-SQL sont intrinsèquement non ordonnés. Bien que dans certaines situations, vous souhaitiez peut-être attribuer des numéros de ligne à titre de référence. Dans cet exercice, c'est exactement ce que vous ferez.***
#
# ####**Instructions**
#
# + Écrivez une requête T-SQL qui attribue des numéros de ligne à tous les enregistrements partitionnés TerritoryName et triés par OrderDate.

# %%
SELECT TerritoryName, OrderDate,
       -- Assign a row number
       ROW_NUMBER()
       -- Create the partitions and arrange the rows
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS OrderCount
FROM Orders

# %% [markdown]
# ####**1. Utiliser des fenêtres pour calculer des statistiques**
#
#
# + ***Dans cette leçon, vous utiliserez les fonctions Windows pour calculer l'écart type et le mode d'une colonne.***
#
# ####**2. Calcul de l'écart type**
#
# + ***Le calcul de l'écart type est une tâche courante en science des données, car il est important de comprendre les distributions statistiques des colonnes numériques. À l'aide des fonctions `Windows`, vous pouvez soit calculer l'écart type pour l'ensemble du tableau, soit pour chaque fenêtre à l'aide de la fonction `STDEV`.***
#
# ####**3. Calcul de l'écart type pour l'ensemble du tableau**
#
# + ***Ici, nous calculons l'écart type de la colonne CurrentQuota pour l'ensemble de la table. Puisqu'aucune colonne n'est répertoriée dans `OVER`, nous n'avons pas inclus `PARTITION BY`, une seule fenêtre est créée pour toute la table. Par conséquent, une seule valeur est répétée dans toute la colonne StandardDev.***
#
# ####**4. Calcul de l'écart type pour chaque partition**
#
# + ***Dans cet exemple, la clause `OVER` partitionne et ordonne par SalesYear, créant ainsi une fenêtre pour chaque valeur unique dans SalesYear. En conséquence, l'écart type est calculé pour chaque fenêtre. Lorsque SalesYear change, l'écart type change également.***
#
# ####**5. Calcul du mode**
#
# + ***Voyons maintenant comment calculer le mode. Le mode est une valeur qui apparaît le plus souvent dans vos données. Contrairement à l'écart type, il n'y a pas de fonction pour calculer le mode. Pour calculer le mode, vous devez d'abord créer une expression de table commune contenant un nombre ordonné de valeurs à l'aide de ROW_NUMBER. Ensuite, écrivez une requête à l'aide d'un CTE pour sélectionner la valeur avec le numéro de ligne le plus élevé. Faisons cela pour calculer le mode de CurrentQuota !***
#
# ####**6. Calcul du mode dans T-SQL (I)**
#
# + ***Tout d'abord, nous créons un CTE. Pour ce faire, nous créons des fenêtres en partitionnant et en classant par CurrentQuota et en attribuant un numéro de ligne pour chaque ligne dans chaque fenêtre. Comme vous pouvez le voir sur le CTE ici, seulement soixante-dix mille apparaissent deux fois, il a donc deux numéros de ligne.***
#
# ####**7. Calcul du mode dans T-SQL (II)**
#
# + ***Vous pouvez utiliser ce CTE pour écrire une requête afin de renvoyer la valeur avec le numéro de ligne le plus élevé, comme illustré ici. Cette requête utilise une clause WHERE pour filtrer les données afin d'afficher uniquement les valeurs égales à la valeur maximale dans QuotaList. Le résultat est soixante-dix mille puisque soixante-dix mille se produit le plus grand nombre de fois, deux fois dans CurrentQuota.***
#
# ####**8. Entraînons-nous !**
#
# + ***Il est temps de calculer l'écart type et le mode par vous-même !***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Calcul de l'écart type**
# + ***Le calcul de l'écart type est assez courant lorsqu'il s'agit de colonnes numériques. Dans cet exercice, vous allez calculer l' écart type cumulé , semblable au total cumulé que vous avez calculé dans la leçon précédente.***
#
# ####**Instructions**
#
# + Créez la fenêtre, partitionnez par TerritoryNameet triez par OrderDate pour calculer un écart type courant de OrderPrice.

# %%
SELECT OrderDate, TerritoryName,
       -- Calculate the standard deviation
	 STDEV(OrderPrice)
       OVER(PARTITION BY TerritoryName ORDER BY OrderDate) AS StdDevPrice
FROM Orders

# %% [markdown]
# ####**Mode de calcul (I)**
#
# + ***Malheureusement, il n'y a pas de fonction pour calculer le mode , la valeur la plus récurrente dans une colonne. Pour calculer le mode :***
#
#   + Tout d'abord, créez un `CTE` contenant un nombre ordonné de valeurs à l'aide de `ROW_NUMBER()`
#   + Écrivez une requête en utilisant le `CTE` pour choisir la valeur avec le numéro de ligne le plus élevé
#   + Dans cet exercice, vous écrirez le `CTE` nécessaire pour calculer le mode de OrderPrice.
#
# ####**Instructions**
#
# + Créez un Mode CTE Pricequi renvoie deux colonnes (OrderPric eet UnitPriceFrequency).
# + Écrivez une requête qui renvoie toutes les lignes de ce CTE.

# %%
-- Create a CTE Called ModePrice which contains two columns
WITH ModePrice (OrderPrice, UnitPriceFrequency)
AS
(
	SELECT OrderPrice,
	ROW_NUMBER()
	OVER(PARTITION BY OrderPrice ORDER BY OrderPrice) AS UnitPriceFrequency
	FROM Orders
)

-- Select everything from the CTE
SELECT *
FROM ModePrice

# %% [markdown]
# ####**Mode de calcul (II)**
#
# + ***Dans le dernier exercice, vous avez créé un CTE qui a attribué des numéros de ligne à chaque valeur unique dans OrderPrice. Tout ce que vous avez à faire maintenant est de trouver le numéro OrderPrice de ligne le plus élevé.***
#
# ####**Instructions**
#
# + Utilisez le CTE ModePrice pour renvoyer la valeur de OrderPrice avec le numéro de ligne le plus élevé.

# %%
-- CTE from the previous exercise
WITH ModePrice (OrderPrice, UnitPriceFrequency)
AS
(
	SELECT OrderPrice,
	ROW_NUMBER()
    OVER (PARTITION BY OrderPrice ORDER BY OrderPrice) AS UnitPriceFrequency
	FROM Orders
)

-- Select the order price from the CTE
SELECT OrderPrice AS ModeOrderPrice
FROM ModePrice
-- Select the maximum UnitPriceFrequency from the CTE
WHERE UnitPriceFrequency IN (SELECT MAX(UnitPriceFrequency) FROM ModePrice)
